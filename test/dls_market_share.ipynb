# %%
import pandas as pd
import numpy as np
import market_share_data
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go

# %%
col_catalist = pd.read_csv('발행잔액_catal.csv', delimiter='!')
# col_catalist.head()

# %%
dls_data = market_share_data.get_data(1)
# dls_data.head()

# %%
px.line(x=kis_month_stat.index.astype('str')
        , y=kis_month_stat.balanceSumDls)
# Out:
# <div>                            <div id="eebba5e4-cfe5-4951-81d4-322dfced9ff6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eebba5e4-cfe5-4951-81d4-322dfced9ff6")) {                    Plotly.newPlot(                        "eebba5e4-cfe5-4951-81d4-322dfced9ff6",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["202201","202202","202203","202204","202205","202206","202207","202208","202209","202210","202211","202212","202301"],"xaxis":"x","y":[616946.0,559026.0,648441.0,646926.0,647674.0,629003.0,663861.0,695414.0,633616.0,603098.0,697242.0,698399.0,249096.0],"yaxis":
# ...

# %%
# fig = go.Figure()

# for i in dls_bal:
#     fig.add_trace(go.Scatter(x=dls_data[dls_data.repSecnNm == '한국투자증권'].date
#                              , y=dls_data[dls_data.repSecnNm == '한국투자증권'].loc[:,i]
#                             , name=i))
    
# fig.show()

# %%
fig = px.line(dls_data[dls_data.balanceSumDls > 10000], x='date', y='balanceSumDls', color='repSecnNm', markers=False)
fig.show()
# Out:
# <div>                            <div id="8807b1ca-2f08-40c2-b792-4624903a69fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8807b1ca-2f08-40c2-b792-4624903a69fc")) {                    Plotly.newPlot(                        "8807b1ca-2f08-40c2-b792-4624903a69fc",                        [{"hovertemplate":"repSecnNm=NH\ud22c\uc790\uc99d\uad8c<br>date=%{x}<br>balanceSumDls=%{y}<extra></extra>","legendgroup":"NH\ud22c\uc790\uc99d\uad8c","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"NH\ud22c\uc790\uc99d\uad8c","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-01-12T00:00:0
# ...

# %%
fig = px.line(dls_data[dls_data.balanceSumDls < 10000], x='date', y='balanceSumDls', color='repSecnNm', markers=False)
fig.show()
# Out:
# <div>                            <div id="c25a6c3c-713d-41af-bb19-53ad035d7d56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c25a6c3c-713d-41af-bb19-53ad035d7d56")) {                    Plotly.newPlot(                        "c25a6c3c-713d-41af-bb19-53ad035d7d56",                        [{"hovertemplate":"repSecnNm=\ud604\ub300\ucc28\uc99d\uad8c<br>date=%{x}<br>balanceSumDls=%{y}<extra></extra>","legendgroup":"\ud604\ub300\ucc28\uc99d\uad8c","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\ud604\ub300\ucc28\uc99d\uad8c","showlegend":true,"x":["2022-01-03T00:00:00","2022-01-04T00:00:00","2022-01-05T00:00:00","2022-01-06T00:00:00","2022-01-07T00:00:00","2022-01-10T00:00:00","2022-01-11T00:00:00","2022-0
# ...
